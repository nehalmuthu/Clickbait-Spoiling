# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.13.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)

# %%
import pandas as pd

# %%
train_data = pd.read_json('/content/train.jsonl',lines=True)
validate_data = pd.read_json('/content/validation.jsonl',lines=True)

# %%
#filter only phrase tags for Q&A task
train_data['tags']=train_data['tags'].apply(lambda x:x[0])
train_data=train_data[train_data['tags']=='phrase'].reset_index(drop=True)

#filter only phrase tags for Q&A task
validate_data['tags']=validate_data['tags'].apply(lambda x:x[0])
validate_data=validate_data[validate_data['tags']=='phrase'].reset_index(drop=True)

# %%
# data processing to get context and spoiler start position
def create_df(dataset):

    col1=[]
    col2=[]

    for idx in range(len(dataset)):
        concatlen=0
        line_occuring=dataset['spoilerPositions'][idx][0][0][0]

        for i in range(line_occuring):
            concatlen+=len(dataset['targetParagraphs'][idx][i])


        starting_position=concatlen+dataset['spoilerPositions'][idx][0][0][1]

        col1.append({'answer_start': [starting_position], 'text': dataset['spoiler'][idx]})


        l=''
        for line in dataset['targetParagraphs'][idx]:
            l+=line
        
        col2.append(l)

    df = pd.DataFrame(list(zip(col1, col2)),
    columns =['answers', 'context'])
    df['question']=dataset['postText'].apply(lambda x: x[0])
    df['id']=dataset['postId']

    json_data=[]
    for index, row in df.iterrows():
        json_data.append({
            'question': row['question'],
            'context': row['context'],
            'answers': row['answers'],
            'id': row['id']
        })

    return json_data

# %%
import json

train_json=create_df(train_data)
validate_json=create_df(validate_data)

with open('train_json.json', 'w') as f:
    json.dump(train_json, f)

with open('validate_json.json', 'w') as f:
    json.dump(validate_json, f)

# %%
from datasets import load_dataset, DatasetDict, load_metric

# %%
# Load the JSON file as a Dataset object
train_dataset = load_dataset('json', data_files='train_json.json')
validate_dataset = load_dataset('json', data_files='validate_json.json')
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-983fcf4a899a01b3/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-983fcf4a899a01b3/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-5ed83ed70ad5fde6/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-5ed83ed70ad5fde6/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Create a DatasetDict object containing the Dataset
train_dict = DatasetDict({'train': train_dataset['train']})
valid_dict = DatasetDict({'valid': validate_dataset['train']})

# %%
from transformers import AutoTokenizer
#model_checkpoint = "distilbert-base-uncased"
model = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128 # The authorized overlap between two part of the context when splitting it is needed.

# %%
def prepare_train_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original context. This will
    # help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != (1):
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1):
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
def prepare_validation_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and maybe padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")

    # We keep the example_id that gave us this feature and we will store the offset mappings.
    tokenized_examples["example_id"] = []

    for i in range(len(tokenized_examples["input_ids"])):
        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])

        # Set to None the offset_mapping that are not part of the context so it's easy to determine if a token
        # position is part of the context or not.
        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]

    return tokenized_examples

# %%
tokenized_train = train_dict.map(prepare_train_features, batched=True, remove_columns=train_dict["train"].column_names)
tokenized_valid = valid_dict.map(prepare_validation_features, batched=True, remove_columns=valid_dict["valid"].column_names)
# Out:
# Map:   0%|          | 0/1367 [00:00<?, ? examples/s]
# Map:   0%|          | 0/335 [00:00<?, ? examples/s]

# %% [markdown]
# # TO DO

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
model = AutoModelForQuestionAnswering.from_pretrained(model)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     627                 # Load from local folder or from cache or download from model Hub and cache
# --> 628                 resolved_config_file = cached_file(
#     629                     pretrained_model_name_or_path,
#
# /usr/local/lib/python3.9/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     408         # Load from URL or cache if already cached
# --> 409         resolved_file = hf_hub_download(
#     410             path_or_repo_id,
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     111             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 112                 validate_repo_id(arg_value)
#     113
#
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_validators.py in validate_repo_id(repo_id)
#     165     if not REPO_ID_REGEX.match(repo_id):
# --> 166         raise HFValidationError(
#     167             "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#
# HFValidationError: Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are forbidden, '-' and '.' cannot start or end the name, max length is 96: 'BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )'.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-e035f94b3197> in <cell line: 2>()
#       1 from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
# ----> 2 model = AutoModelForQuestionAnswering.from_pretrained(model)
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     439                 _ = kwargs_copy.pop("torch_dtype")
#     440
# --> 441             config, kwargs = AutoConfig.from_pretrained(
#     442                 pretrained_model_name_or_path,
#     443                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     914         kwargs["name_or_path"] = pretrained_model_name_or_path
#     915         trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 916         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     917         if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     918             if not trust_remote_code:
#
# /usr/local/lib/python3.9/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     571         original_kwargs = copy.deepcopy(kwargs)
#     572         # Get config dict associated with the base config file
# --> 573         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     574         if "_commit_hash" in config_dict:
#     575             original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# /usr/local/lib/python3.9/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     647             except Exception:
#     648                 # For any other exception, we throw a generic error.
# --> 649                 raise EnvironmentError(
#     650                     f"Can't load the configuration of '{pretrained_model_name_or_path}'. If you were trying to load it"
#     651                     " from 'https://huggingface.co/models', make sure you don't have a local directory with the same"
#
# OSError: Can't load the configuration of 'BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )' is the correct path to a directory containing a config.json file

# %%
batch_size=16

# %%
model_name = "bert-base-uncased"
args = TrainingArguments(
    f"{model_name}-finetuned-squad",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
    push_to_hub=True,
)

# %%
from transformers import default_data_collator

data_collator = default_data_collator

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_train["train"],
    eval_dataset=tokenized_valid["valid"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)
# Out:
# /content/bert-base-uncased-finetuned-squad is already a clone of https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/bert-base-uncased-finetuned-squad is already a clone of https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 11:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.936600</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=600, training_loss=1.8179331588745118, metrics={'train_runtime': 701.867, 'train_samples_per_second': 13.665, 'train_steps_per_second': 0.855, 'total_flos': 1879572895391232.0, 'train_loss': 1.8179331588745118, 'epoch': 3.0})

# %%
trainer.save_model("test-squad-trained")
# Out:
# Upload file pytorch_model.bin:   0%|          | 1.00/415M [00:00<?, ?B/s]
# Upload file runs/Apr19_19-57-35_93a65849b10e/events.out.tfevents.1681934301.93a65849b10e.1087.0:   0%|        …
# To https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad
#    5cb8073..24fc8a0  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad
#    5cb8073..24fc8a0  main -> main
#
# To https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad
#    24fc8a0..bc59f5d  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/aravind168/bert-base-uncased-finetuned-squad
#    24fc8a0..bc59f5d  main -> main

# %%
from tqdm.auto import tqdm
import numpy as np
import collections

def postprocess_qa_predictions(examples, features, raw_predictions, n_best_size = 20, max_answer_length = 30):
    all_start_logits, all_end_logits = raw_predictions
    # Build a map example to its corresponding features.
    example_id_to_index = {k: i for i, k in enumerate(examples["id"])}
    features_per_example = collections.defaultdict(list)
    for i, feature in enumerate(features):
        features_per_example[example_id_to_index[feature["example_id"]]].append(i)

    # The dictionaries we have to fill.
    predictions = collections.OrderedDict()

    # Logging.
    print(f"Post-processing {len(examples)} example predictions split into {len(features)} features.")

    # Let's loop over all the examples!
    for example_index, example in enumerate(tqdm(examples)):
        # Those are the indices of the features associated to the current example.
        feature_indices = features_per_example[example_index]

        min_null_score = None # Only used if squad_v2 is True.
        valid_answers = []
        
        context = example["context"]
        # Looping through all the features associated to the current example.
        for feature_index in feature_indices:
            # We grab the predictions of the model for this feature.
            start_logits = all_start_logits[feature_index]
            end_logits = all_end_logits[feature_index]
            # This is what will allow us to map some the positions in our logits to span of texts in the original
            # context.
            offset_mapping = features[feature_index]["offset_mapping"]

            # Update minimum null prediction.
            cls_index = features[feature_index]["input_ids"].index(tokenizer.cls_token_id)
            feature_null_score = start_logits[cls_index] + end_logits[cls_index]
            if min_null_score is None or min_null_score < feature_null_score:
                min_null_score = feature_null_score

            # Go through all possibilities for the `n_best_size` greater start and end logits.
            start_indexes = np.argsort(start_logits)[-1 : -n_best_size - 1 : -1].tolist()
            end_indexes = np.argsort(end_logits)[-1 : -n_best_size - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                    # to part of the input_ids that are not in the context.
                    if (
                        start_index >= len(offset_mapping)
                        or end_index >= len(offset_mapping)
                        or offset_mapping[start_index] is None
                        or offset_mapping[end_index] is None
                    ):
                        continue
                    # Don't consider answers with a length that is either < 0 or > max_answer_length.
                    if end_index < start_index or end_index - start_index + 1 > max_answer_length:
                        continue

                    start_char = offset_mapping[start_index][0]
                    end_char = offset_mapping[end_index][1]
                    valid_answers.append(
                        {
                            "score": start_logits[start_index] + end_logits[end_index],
                            "text": context[start_char: end_char]
                        }
                    )
        
        if len(valid_answers) > 0:
            best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
        else:
            # In the very rare edge case we have not a single non-null prediction, we create a fake prediction to avoid
            # failure.
            best_answer = {"text": "", "score": 0.0}
        
        # Let's pick our final answer: the best one or the null answer (only for squad_v2)
        if not True:
            predictions[example["id"]] = best_answer["text"]
        else:
            answer = best_answer["text"] if best_answer["score"] > min_null_score else ""
            predictions[example["id"]] = answer

    return predictions

# %%
raw_predictions = trainer.predict(tokenized_valid['valid'])

# %%
final_predictions = postprocess_qa_predictions(valid_dict['valid'], tokenized_valid['valid'], raw_predictions.predictions)
# Out:
# Post-processing 335 example predictions split into 768 features.
#   0%|          | 0/335 [00:00<?, ?it/s]

# %%
#to see output. comment if not needed.

final_predictions
# Out:
# OrderedDict([('857559227384160256',
#               ', since the goal is to get you back into the salon. When in doubt, ask at'),
#              ('388301310635671553',
#               ', not by the ethanol itself, but by ethanol’s first metabolite, acetaldehyde. Ethanol is metabolized into acetal'),
#              ('553676574290354177', 'Recipe created by Art SmithSer'),
#              ('4kt69b',
#               'lettuce and bowls of soup and Mr. Obama is holding up'),
#              ('4wagdb', ', according to both the'),
#              ('1100188040002123_1123063127714614',
#               ', until it dissipated rapidly into the cold air. The gas could be clearly seen against the dark-colored ea'),
#              ('473452702002065409',
#               ', which will be published in full in the'),
#              ('170016066732231_174009032999601',
#               ', and the two obvious paths are to a) Re-release a tweaked version of iOS 9.3.2 or b'),
#              ('474005518713769985', ', The'),
#              ('4kq6db', ', you. Forget Beefy Crunch Burritos ; T'),
#              ('438689079539286016',
#               ', until now.Beginning earlier this month and continuing through June 15, the macab'),
#              ('403757856597372928',
#               ", we've seen gorgeous Rag & Bone styling interpretations by industry powerhouses like Lily Aldridge, Karolina Kurkova"),
#              ('398323375371608064',
#               'left to wonder why all of Hollywood seems to be cutting long locks into drastically different (albeit sometimes chi'),
#              ('4wennf',
#               ', that there was no way he’d manage to raise Biscuits on his own. Undeter'),
#              ('384053590207119361',
#               ',000. It was expected to sell between $75,000 - $'),
#              ('590544984098635776',
#               'has a firm departure date from Comedy Central’s "The Daily Show." The comic'),
#              ('555426985967894529', ', and I respect that and will'),
#              ('452637109074272256',
#               ', but it was worth the effort. It has made a significant difference in my communication with my husband, and now, my kids. Above'),
#              ('54zbhl',
#               '," the editorial said.The Arizona Republic is not the'),
#              ('379437666896728064',
#               '," according to LifeWay. Though he believes the Bible'),
#              ('1100188040002123_1112661478754779',
#               'Telegraph:"If rapamycin has a similar effect in dogs – and it’s important to keep in'),
#              ('388798300750872576',
#               ', but Obamacare allows employers to offer plans that'),
#              ('671442190967644160', ', is a "hater," a "bigot," an "'),
#              ('484495058884759552',
#               ', and I don’t shop there," Ms. Lepucki said. "But I love Goodreads. For'),
#              ('4n8r1i',
#               'Colts before the 2009 season started. He later signed with'),
#              ('390958297249247233',
#               ", this year would bring a new champ for the title of world's largest pumpkin.According to a press release by"),
#              ('553532253817806848',
#               ', dropping $25K on 2 dogs.Paris just nabbed 2 perky Pomeranians and accompanying b'),
#              ('443941579582353408', ', according to'),
#              ('836506226728947713', '. You have'),
#              ('544pwd', ', followed by'),
#              ('54inls',
#               ', such as Zac Posen and Stuart Weitzman.That shift has had some industry experts scratching'),
#              ('51i904',
#               ', there are still a lot of open questions about how and why humans get prion diseases.For'),
#              ('51h5t1', ', which makes the plant harmful.So, be'),
#              ('4l2he3',
#               ', located at 736 Central Ave.Pro-life writer Mollie Hemingway had a little fun at Planned Parenthood’s expense:Those Haz'),
#              ('832305003567652_880524278745724',
#               ', not to mention a lifetime of family moments suddenly interrupted by questions that start with "Hey, aren’t you'),
#              ('852964184249835524', ', to'),
#              ('379746538517323776',
#               ', and starve the bad. (Within weeks, the Enterobacter was completely wiped out.)"You Really Love A Smooth Grena'),
#              ('418989757520027649', '," O’Malley said to'),
#              ('812123578455957504',
#               'Is NVIDIA Corporation Maintaining Momentum? We’ll'),
#              ('572971196188393472', '(22 percent), followed by'),
#              ('170016066732231_272090746524762',
#               "cardboard, we can't decide whether to laugh or cheer. This video now has over 9 million views.We have to"),
#              ('4op73i',
#               ', compared to smaller startup companies that could not afford to pay.Three years ago when these rules were being formulated by'),
#              ('4kbp5t', ', but also brought us one of the'),
#              ('590963499171520512',
#               ', and what has changed since its infancy," Bottke said.The scientists detailed their findings in the April 17 issue of'),
#              ('385938226277392384',
#               ', 13 and 15-year-olds having smoked pot in the last year.For'),
#              ('380112609607155712',
#               ', effectively, an iPhone 5. Same A6, same camera, same just about everything — except for the most obvious difference, its array of'),
#              ('4ozh3u',
#               ', she decided to take some of her old pennies and glue them to the'),
#              ('392438344913022976', ', according to'),
#              ('410203680223145985',
#               ', Lauren applies a lighter shade as a base to'),
#              ('170016066732231_208703622863475',
#               ', I just want to do the stuff that really matters." He went on to'),
#              ('405901363873611776',
#               ', as well as type 2 diabetes and cardiovascular disease. The'),
#              ('380536599009705984',
#               'year. Regulators, including the U.S. Securities and Exchange Commission and the'),
#              ('50picj',
#               ', there’s still an excellent possibility drivers can qualify for fair interest rates.But do you think your auto loan company will'),
#              ('4uy3cu',
#               ', upon reaching Cinnabar Island, players have to navigate their ways through the Pokémon Mansion, a burned mansion where a Pokémon researcher used to'),
#              ('376532149887049728',
#               '. Another $252,000 came off at the beginning of'),
#              ('4mx8f0',
#               ', explaining why he decided to join the group after having opposed Trump, according to the New York Times.Is that the'),
#              ('4xiczl', ', and that'),
#              ('375649248525557760',
#               ', George Clooney and your held breath. The'),
#              ('4xevbt',
#               ', is the numbers are all self reported, so the hopeful Wisconsinite in me wants to'),
#              ('681204363902238720',
#               ', the charities receiving the money have said (AFP Photo/)London (AF'),
#              ('405558716897820672', ', turning her into'),
#              ('4vdlog',
#               ', but modified for the scene.It made for great watching even shooting the stunts which are almost entirely practical (VF'),
#              ('378184351545954305', ', Calif. and Raleigh'),
#              ('426590828782694400', ', and would like to'),
#              ('849230685204608_883155208478822',
#               "on the planet', they also shit their pants when they hear about the Israeli army"),
#              ('397203892938604545',
#               '," Michael B. Jordan, who admitted to the'),
#              ('378173406858203136', 'lady on the'),
#              ('881531941974661_904524699675385', ''),
#              ('376216574828376064',
#               ', when Attorney General Eric Holder informed the governors of Washington and Colorado that'),
#              ('800048986762423_811478622286126',
#               'Battlefield 1 on June 12 at 5 PM ET. The live stream will be followed by EA'),
#              ('388350033805840384',
#               '., Too $hort, and Twista6. "MANiCURE"7. "'),
#              ('546o7t',
#               ', falsely claiming to have lost hundreds of friends that day; to have seen thousands of Muslims cheering the fall of the twin towers; and to'),
#              ('4jp27b', ', we can’t help but shake our head at it.T'),
#              ('832305003567652_854402051357947', ', below'),
#              ('431829764018810881', 'is for her over-the'),
#              ('377644760929824768',
#               ', she said, "could look totally dynamic, professional and serious all at the'),
#              ('50accr',
#               ', though: While Donald Trump has thus far appeared to accomplish the'),
#              ('4tuj89', ', known as: (i)'),
#              ('571535305729310720',
#               ', CNET reports. The Android version will support Android TV, while the desktop version will'),
#              ('455387195051085824', ','),
#              ('4j1lgb', ', but that'),
#              ('402132074368225280',
#               ', but those bad boys hardly come cheap.To'),
#              ('386321975167049728',
#               ', researchers say breast cancer rates increased 0.2 percent among black women but remained stable among whites between 2006 and 2010, the'),
#              ('846762500372729857', 'of her, earning her the'),
#              ('832305003567652_857966724334813', ', 2016According to'),
#              ('377825111468167170',
#               "days, I'm not going to worry about it. There are far bigger fish to"),
#              ('405505043748507648',
#               '," before trailing off, saying, "but she doesn\'t seem ... she seems cooler than ..." Ho'),
#              ('557tk3',
#               'has an innovative new solution to solve the gender gap in tech. The'),
#              ('4r9a5c',
#               ", if you're a man looking for a committed relationship with a woman, you shouldn't hesitate to flaunt the fact that"),
#              ('47rz2v',
#               'colour co-ordinating his hair with the *many* shirts he wore during his time in the Premier League.(Martin Rick'),
#              ('170016066732231_204801526587018',
#               ', my medicine cabinet is absolutely overflow'),
#              ('429393582953619456',
#               ', saying that the growing Latino population will "'),
#              ('390964121476157440',
#               ', is untreatable.Fortunately, the likelihood of an average person randomly encountering the new toxin "is exceedingly small," Hooper told The'),
#              ('395790166058868736',
#               ', while the far right calls for enterprise."One of the'),
#              ('4t5reh', ', it was followed by'),
#              ('641931005461438464',
#               ', as this month’s "New Establishment" issue is all about power. In this context, nothing says power quite like telling'),
#              ('4lv7mh', 'is late in the'),
#              ('845072946053943296',
#               ', has created a machine its founders think is'),
#              ('411664028734615552',
#               ', swallowing him entirely.In August 2012, a man in Taiwan was killed after falling into a huge sinkhole in the wake'),
#              ('696888225395253248', '. Belichick, too." And then'),
#              ('4n66f9',
#               'lebs, as well as the source of legend — Mariah Carey'),
#              ('849230685204608_878461742281502',
#               ', Aamir and Salman we have huge liking towards each other. I also feel they are bigger stars than me. If you ask me I will'),
#              ('505545482979561_516236938577082', ', often in the'),
#              ('4n1j9c',
#               ', Grammer reveals the odd way in which his penchant for backstage Tony Bennett impressions circuitously led toco-creator Sam Simon offering him the'),
#              ('381170307307827200',
#               ', as our theater company is a nonprofit with a very limited budget. What did we have to'),
#              ('387032239147454464',
#               ', because truly you dance together, not by yourself.Everyone who is there has opted in simply because'),
#              ('51i0o5',
#               "Sunday. That's a whole different story. I like him as"),
#              ('765236645159378944', ', with Braille inscriptions on the'),
#              ('374425931613364224',
#               ", they won't say 'I have no choice and this is the"),
#              ('392397011065921536',
#               ', called GSAs for short."The shirt itself is not offensive. It’s what it was advocating for and questioning whether or'),
#              ('170016066732231_249329898800847',
#               ', or one that may be sold with your spray-on polish.Next, shake up the'),
#              ('962012720563208_1005501169547696',
#               'seat despite only attending four days in Congress when he was still the representative of SaranganiManny Pacquiao stated that his passion was the'),
#              ('604664354747871232', ', but this video from Asa'),
#              ('854160817360707584',
#               ", Runner's World reports.The flag appears to have signatures and messages written on it to Sgt. Sanchez, one message"),
#              ('800048986762423_809618749138780',
#               ', but anything cannot be confirmed until we hear it from Blizzard'),
#              ('408112290924204034', ', it does... to your ego.To'),
#              ('375094646113705985', ', though, that was for the'),
#              ('590136994585567232',
#               ', Bradford and Matt Barkley have combined to rush for 671 yards in their careers.Something else worth keeping in'),
#              ('379427836500930560', ', captioning'),
#              ('517kn6',
#               ', I’ve literally never won a game of Scrabble in my life.[The'),
#              ('832305003567652_851078631690289',
#               ', aka "Chewbacca Mom" is laughing'),
#              ('385186000726937600', ', GET SET, BID!'),
#              ('386519747921457152',
#               ', 2013. That is, if you have $40 to $60 million sitting around."What’s great about this country is that'),
#              ('4mq11h', ', but they ended up becoming the'),
#              ('805842201611800576',
#               ', for innovations in sexual pleasure and fun.To'),
#              ('881531941974661_903275403133648',
#               ', and now exist only in Indonesia.In'),
#              ('687865017350393856', ', opening'),
#              ('4t3qv4',
#               ', but that its devastating effects were different than commonly thought, reports The'),
#              ('396395351667531776',
#               ', it looks like Jesus is "the most high" on Twitter -- except for Justin Bieber'),
#              ('817631862226989057', "with that birthday, don't you!Ho"),
#              ('501sed',
#               'plc. Permission to use quotations from this article is granted subject to appropriate credit being'),
#              ('4kiig0', ''),
#              ('819113738901004288', ', it would be awesome to'),
#              ('527b89',
#               'condition in the form of honest lyrics wrapped around soaring melodies as they are for'),
#              ('703213550664290304',
#               ', with 47.2% is just five points ahead of Bernie Sanders.There is, of'),
#              ('378527766309662720', ', according to'),
#              ('549418942511710208',
#               '. The Hobbit: The Battle of the Five Armies $41.4 million2. Unbroken $31.7 million3. Into the'),
#              ('4tvvhd',
#               ', and breaks the positive associations with cigarettes that the mind has formed. This is replaced by'),
#              ('383314706129108994',
#               'Shorty," and "Rum Punch" (later filmed by Quentin Tarantino as "Jackie Brown'),
#              ('387703655299678208',
#               ', and the still-active volcano and ruined town have turned into'),
#              ('533272568535711744',
#               'is today. The realignment of power among bond managers is only just beginning. If'),
#              ('812834949669724160', ', as the'),
#              ('855010657883869184',
#               'has a second date to attend. Hall said:He asked for a second date in the hospital. I was extremely honored. What means the most'),
#              ('54k7x5',
#               ', "Wow! That\'s the prettiest Wedding dress ever! She should have gotten First place! So creative! I Pray'),
#              ('4xo9bv', ', as the'),
#              ('625634669216854017', ', adding'),
#              ('4qpvuw',
#               'family and a few close friends, I’m sure it was fun for Khloe to'),
#              ('5598ba',
#               ', in fact the bricks are as solid as the traditional clay and shale mix but far more eco-friendly.Managing to maintain the'),
#              ('505545482979561_516860008514775',
#               ', and 65 percent of that total comes from raising beef and dairy cattle.NPR'),
#              ('170016066732231_229546794112491',
#               ', slice it horizontally to prevent the juices from running out.)1 pound thick-cut bacon4 large leaves of Bi'),
#              ('392311087657279488',
#               ', as the Los Angeles Times reports:In November 1999, he was convicted of driving under the influence. Last'),
#              ('170016066732231_242426779491159',
#               ', it has overtaken tobacco as the number one currency in US prisons, The'),
#              ('4qjh5h', "Whitesnake's Here I"),
#              ('384228827633041408', ', meaning they wanted to'),
#              ('421379299350810624',
#               ". I pass by the open hotel lobby that's air-conditioned in the summer and heated in the"),
#              ('53zrds', ', Sr. spoke to the'),
#              ('553c0o', ', according to a team of researchers from the'),
#              ('433278625488863232', ', following a series of photos Bieber'),
#              ('380045714526457857', '," Christian Thompson'),
#              ('497233573045628928', '" as'),
#              ('377647990275469312', ', including a Mum'),
#              ('800048986762423_811976758902979',
#               ', only a few days after the game’s official launch, and it’s already coming'),
#              ('721323075246112769', '," noted the'),
#              ('51a6xo', ', and maybe even win the'),
#              ('54dxh0',
#               ', or store them in an airtight container in the refrigerator up to'),
#              ('462342339781201920',
#               ', May 4, is "Star Wars" Day (aka May the Fourth Be With You'),
#              ('4lro2v',
#               ', learning to ignore people petting him," Hailey explained. "We understand our dogs are super cute, but they are really important for'),
#              ('53e76y', ', emerging to a place I’m happy to'),
#              ('170016066732231_253847418349095',
#               ', I will never ask you who is taking care of them. Because I will'),
#              ('392491490242347009',
#               "today Google's page is dedicated to Celia Cruz! — Theresa Socash (@tsoca"),
#              ('4jrcgc',
#               'whether to make the pages public since 2014 and are due to deliver a recommendation to the president. Whatever the recommendation, the White'),
#              ('170016066732231_181078432292661',
#               '," says veterinarian New York City Richard Goldstein. The'),
#              ('432690060711170048',
#               ', Sam took to Twitter to thanks those who helped him in coming out.I want to thank everybody for their support and encouragement,especially @'),
#              ('4k1dnt', ', due to its excellent reputation.To'),
#              ('517wb2',
#               'rainy day.Selena paired her long patent jacket with a Jennifer Fisher silver knot choke'),
#              ('403923146090115072',
#               ', according to a new HuffPost/YouGov poll that also finds most think human activity is at'),
#              ('393952699391016960',
#               ', Finland ranked #2 with a score of 0.8451.3. Norway Flickr: Moyan_Bren'),
#              ('4ospl7',
#               ', rather than eradicating infection at their factory farms.And don’t'),
#              ('4wu5zv', ', there’s going'),
#              ('50zybd',
#               ', as student-debt figures have hit staggering levels.But most conversations center on ballooning tuition costs, rather than a less well-known expense that'),
#              ('613054300655218688',
#               "version of Texas you've seen in movies. Austin is better described as the"),
#              ('516pm8',
#               ', which basically takes malnutrition and dehydration off the'),
#              ('4qap0d',
#               ', in a statement. "Our work had nothing to do with looking for a pigment.He added'),
#              ('382166003905331200', ', and I expect we will'),
#              ('401040284865146880', ', Kristina is collapsing into happy'),
#              ('844109892399324_887681204708859',
#               ", should've been trying to tear her head off"),
#              ('395049809632964608',
#               ', when the tour bus struck and killed him. ABC News confirmed the tragedy with the'),
#              ('618428639483424768',
#               ', and work my way west through North America. I would visit 36 states in the United States and stop in Canada and Mexico along the'),
#              ('170016066732231_232214433845727',
#               ', we’re talking calculators that rival my electricity bill. But I sigh, watch the'),
#              ('832305003567652_880543728743779',
#               'BAGEL HOW DO YOU THINK IM GONNA'),
#              ('4moj1o',
#               ', causes them to starve with full stomachs."I n addition to this statement, Nicola Ho'),
#              ('388040438298324992',
#               'Miley." "Royals" and "Wrecking Ball" were each singer\'s first No'),
#              ('520592421319876608', ', according to a 2013 survey by Bradley'),
#              ('575047627059896321',
#               ', but I have a home and that is my responsibility to'),
#              ('54hbh4', ', and mentioned his father and'),
#              ('618393368599597057',
#               'stretches a generous 35 feet and combines the'),
#              ('562692085917425664',
#               'L.G.B.T. faculty and staff group at Harvard, believes that Vermont’s changes are nothing less than lifesa'),
#              ('1100188040002123_1107266289294298', ', and it will'),
#              ('4m49gm',
#               ', defines uncommon. Even in the economically stretched times of 2009-10, the PGA signed lucrative sponsor agreements. Now, the tournament seems headed on the'),
#              ('849230685204608_883114155149594',
#               ', or else she would have made a disapproving and embarrassed face we all make when our fathers try too hard to'),
#              ('52c61r', ', it could have killed her.By the'),
#              ('4mo5q3',
#               ", but since it's summer, it's gotta feel wonderful to clipper-cut the"),
#              ('427972855876558848',
#               ', as well as same-sex couple Spencer Stout'),
#              ('386267518580424704', ', Timmermans said, and would seek the'),
#              ('170016066732231_220684304998740', '(@MrEmi'),
#              ('622416023829020672',
#               ', at age 17, she became a hostess at a local Hoote'),
#              ('409836726140805120',
#               ', Pilotto and his co–creative director Christopher De Vos pose with models showing off a drop-waist dress, a crop'),
#              ('4klknb', 'Jennifer Lawrence: not very talented!"Just you'),
#              ('52k5qq',
#               'today , 505 told fans to "avoid" Terraria\'s online multiplayer as the company finds a permanent fix."We are sorry to'),
#              ('554gk6', ', and then'),
#              ('4q3xfu',
#               ', his wife insisted he add it to his menu.But it remained a strictly of-the-house specialty. Despite the'),
#              ('4n9cqn',
#               ', making it one of the most popular films ever made. Continued On Next Page > Blended From Around The Web Comments FacebookBack to'),
#              ('459468554631647232', ''),
#              ('818496308377833472',
#               ', and interest seems to drop off. The Sun on Sunday surveyed 3,'),
#              ('4lvqjq',
#               'with the ice and snow that would be much more interesting than your ordinary run of the'),
#              ('407908413322960897', ', which also has what it claims to'),
#              ('428635906502049792',
#               ', this is great news for consumers who want that J. Crew quality on a budget and even'),
#              ('4lvkum',
#               'is there. It is not big enough to hold anything substantial like money, keys or a wallet - so what is it supposed to be used for'),
#              ('844109892399324_889350541208592', ', but certainly'),
#              ('484865645046407169',
#               '," has confirmed that the dialogue has been updated and will be fixed by the game’s Sept. 9 release. On its blog, the developer'),
#              ('511088720544821248', ', he wrote, "Maybe thirty'),
#              ('401370516100898816', '," he added.Pretending to'),
#              ('4lrdjx',
#               ', alleging a violation of their civil rights, according to the newspaper.In response, the'),
#              ('578311702372052994',
#               ', or getting him to do my makeup. And I think it was just a constant focus on the good bits that'),
#              ('375645819648479232',
#               ', the crowd began shouting: "José José lives! José José lives!"Once back on stage, the star didn’t hesitate to'),
#              ('728601615582662656',
#               "Greenwood's album with Israeli composer Shye Ben Tzu"),
#              ('443112070146699264',
#               ", which sits out on the water off Zanzibar's Michanwi Pingwe beach. They serve fresh fish and pastas and drinks gal"),
#              ('615906959791816704', ', according to'),
#              ('378392279876005888', ", explained Heigl's difficult behavior,"),
#              ('4w69a8',
#               '’ outlines his weight loss journey in hilarious detail but actually cautions readers that he does'),
#              ('4ww4tu', ', so I had one more year. I had sort of had it in'),
#              ('54yggl', ', and the'),
#              ('4r59nu',
#               'if they were your own. And in choosing your next book, make it a tough one.Your brain will'),
#              ('449296576163618816', 'Conner now holds the'),
#              ('4s5gb5',
#               'there in the future – I just found it really funny!’Farmfo'),
#              ('380703825654743040', 'ling went on to'),
#              ('52evc0',
#               ', which the TSA then collects. And it all adds up to a shockingly large amount. According to'),
#              ('616067648904896516',
#               ', behind only Colorado.Weed shops in Oregon are so plentiful that'),
#              ('390523516732194816', ", you're greeted with"),
#              ('5147nr',
#               ', having retired in his home country with Fluminense last year, but he remains one of the'),
#              ('384116690037915648',
#               'Thursday. P pic.twitter.com/r76ITtI6q9 — Farrelly Brothers (@farrellybros) September 26'),
#              ('54pihs',
#               ', but we have to think about it to help kids like Emily.So if you see anyone with a golden ribbon, you can now know that'),
#              ('4t3ohh', ', followed by'),
#              ('668487760135782401',
#               'meal1⁄2 teaspoon cinnamon powder1⁄2 teaspoon cardamom powder1⁄2 teaspoon grated'),
#              ('622578942885687296', 'break-in has been much appreciated."If'),
#              ('559bc3', ', like the wireless earbu'),
#              ('426569440109821952',
#               ', I needed to step up my moisturizing efforts. So when the Sephora Instant Moisturizer landed on my desk, I twisted the'),
#              ('4we17m',
#               ", while Organa -- Princess Leia's adopted dad -- was blown to"),
#              ('646018779005235200', 'is asked to'),
#              ('719302139173072896',
#               'Telegraph , have speculated that she was referring to Hillary Clinton who worked to improve lives of'),
#              ('4xjied',
#               ', that I can’t eat pizza, can you get over that?"She went on to'),
#              ('465028084585234432',
#               ', still sounds awesome.2. Being at a high altitude just makes things more'),
#              ('844109892399324_845482578928722',
#               '. Probably a smart move.What would you do if something like this ever happened to you? I, for'),
#              ('813127266544873473',
#               'today.The accused, identified as Tulsiram Manere was held last night, Inspector S V Jadhav of'),
#              ('5265hx',
#               ', who obviously meant so much to her."Tributes also poured in from from British Universities & College Sport (BUCS) – the'),
#              ('405553764137840641',
#               '," Ervin told the Sun-Times.Health officials, meanwhile, were dismayed that the tax on cigarettes wasn\'t higher."The'),
#              ('52xko0',
#               'Sullivan, Executive Director of 1,000 DaysBarbara Bush, daughter of former President George W. Bush and the'),
#              ('810282611591483393',
#               ', I walked toward the illuminated cubbies and within minutes my name was displayed on the screen above them, alerting me that'),
#              ('832305003567652_889179127880239',
#               ', you can download 7 Best Stocks for the Next 30 Days . Click to'),
#              ('407878099464769536',
#               ', resulting in a facility equipped with rock walls and hot tubs, while the'),
#              ('547135273948438529', '," the outlet went on'),
#              ('800048986762423_830793070354681',
#               ', else Blizzard has up their sleeve. Maybe'),
#              ('630010636634836992',
#               ', or even eliminate it. "In particular, reductions were seen in blood acetaldehyde levels, the toxic metabolic thought to'),
#              ('396020159493570560',
#               ', I found it so liberating and empowering."McIver posts lots of photos of his new go-go life to'),
#              ('414871096408555520', 'to No. 1). The Queen of the'),
#              ('414838178827083776',
#               'Gray of the Washington Animal Rescue League in D.C., really wanted for Christmas was on the floor -- in the'),
#              ('823752189139034113', '," she said, "but I knew the'),
#              ('4wq5y8', ', and to'),
#              ('4ixrkf',
#               ', it will really — you lead by example, always lead by'),
#              ('505545482979561_526359100898199',
#               ', amid questions over the contract, the tuss'),
#              ('4k6kkr', ''),
#              ('556x1o',
#               ', if you use those fancier plastic- or metal-made chopsticks, you always have holders that have cute designs to'),
#              ('387043044769267712',
#               "to room, you'll discover how to affordably clean your home using all-natural, homemade cleaners; get rid of"),
#              ('381046028587503617',
#               'term.Buffett also endorsed Bernanke back in 2009, in the heat of the crisis, calling him "the'),
#              ('1100188040002123_1111272498893677', ', and is an endoca'),
#              ('421783445094690817', ', will'),
#              ('170016066732231_256666081400562',
#               ', and every individual and couple has their own challenges to'),
#              ('820502522343411712',
#               ', indicating to researchers that genetics may be at work.Fortunately'),
#              ('4u3b4k', 'plate:Some pens have a hole in the'),
#              ('170016066732231_232215157178988',
#               ', feathered or in between) make sure you have a conversation with your loved one first. This ensures that'),
#              ('844109892399324_922420374568275',
#               ', and who first developed a specific mutation that accounts for the now widespread iris coloration.Originally, all humans had brown eyes, although genetic variation relating to'),
#              ('4oveaq',
#               ', there is also a dark side. With every new product that is released in the market, there is a good number'),
#              ('53q1gm',
#               ', the Clinton News Network was putting words in Trump’s mouth — one word in'),
#              ('377275214800777216',
#               ', it stood out particularly on the redheads.With such a vibrant eyeshadow color on the lids, it is key to keep the'),
#              ('857281898141405185',
#               ', but Judge has joined Stanton as a player you can’t'),
#              ('551ndh', ', followed by ice'),
#              ('420579512909193216',
#               '," and previously did similar versions of her own songs. Take'),
#              ('4mionu', '(6.88)."Those led to'),
#              ('4s7qqd',
#               ', according to recent research, this fast-food is also the leading cause for four types of cancer.Hot dogs were introduced by German immigrants in the'),
#              ('373517547380826113',
#               ', Benicio Del Toro and Lee Pace are among the film\'s live-action stars. "Guardians of the Galaxy" will also'),
#              ('52c6qz', ', by'),
#              ('384901071199817728', ',240 if you'),
#              ('613393346669772800', '. But it served as'),
#              ('698190806209921024', ',According to'),
#              ('47n5eu', ", and to our surprise it's in the"),
#              ('399322475961397248', "to change.The students' video adds to"),
#              ('52wcr5', ', followed by'),
#              ('800048986762423_827786360655352',
#               ', it sounds a bit weird, we are forced to believe that the game might have a ‘capture the'),
#              ('857700992179195907', ', it will'),
#              ('402650465680490496',
#               ', for a fourth and second season respectively.To'),
#              ('4vh7tm',
#               ', could lead to weight gain, and the early onset of diabetes.So how do Britons fare?The'),
#              ('696888948732338176',
#               ', smirking. "OK, you’re not allowed to say and I never expect to hear that from you again. I'),
#              ('589062531014066177', ', according to'),
#              ('388756523607797762',
#               ', going from green to one side of the space to red'),
#              ('676572879064961026',
#               ', but with a little cajoling from Stern, she revealed Colin Quinn was the'),
#              ('4pbbod', ', Argentina.He found the shell partly covered in'),
#              ('554ep7', ', that’s the only one I’m really waiting'),
#              ('1100188040002123_1110492208971706', '’t'),
#              ('800048986762423_896532303780757',
#               ", doesn't mean you have to. The development team wants players of the new game to"),
#              ('4lx1le', ', or Jingling Bao'),
#              ('831194520750546944', 'limbs of the planet.Owen Gaff'),
#              ('1100188040002123_1112696008751326',
#               ', and also improved the water group’s insulin resistance, the benefit of which could be leveraged in various medical treatments.This is among the'),
#              ('376543708663283712', '" and well ahead of Ben Af'),
#              ('4mucb0',
#               ", because rags are often headed to the garbage.So get yourself a good old rag and keep it in your vehicle. You'll"),
#              ('570230039624740864',
#               ', where she joined local law enforcement officials to'),
#              ('391248046492635136',
#               ', features a striking gray winter coat, a voluminous wool'),
#              ('830403516636147718',
#               ', and you go and try to make the best impression you possibly can in the'),
#              ('394888877107716097', ", and it's"),
#              ('438154712895221761',
#               ", according to a report in local paper St. Cloud Times, is based on fears that marijuana's medical benefits are still unpro"),
#              ('4aung2', ', from Sandwell Police, told the'),
#              ('379438103414718464',
#               'Bennett, John Milhiser, Kyle Mooney and "SNL" writer Michael Patrick O\'Brien.The Times revealed that'),
#              ('563469314997886977', '," Allen told the Daily Sun.Dan Barr'),
#              ('54wzm4', ', you’re a true ‘Simpsons’ fan."For'),
#              ('530kc0',
#               ', they had a warm, safe environment and were off the streets for good. This remarkable story reminds me of Hero, the'),
#              ('170016066732231_199315770468927',
#               ', however, you experience a weird phenomenon that'),
#              ('477585615706685440',
#               ", when the season finale aired.Meanwhile, WWE commentator Jim Ross suggested that Patterson's declaration came as no"),
#              ('843295362613952512',
#               ', does take responsibility. ‘I wasn’t saying that just quoting somebody else.’ When you have the White'),
#              ('473633855145263105',
#               ', 2014Brown also made sure to mention that late-night hosts themselves are not necessarily responsible for which guests appear on their shows.And let me'),
#              ('419294849125580800',
#               ', not just crimes reported by a single municipal agency."We won\'t spoil the number one spot for you -- click over to'),
#              ('4o2q65',
#               ', which stimulates both sexual partners. So far, so Ann Summers Lovely Inc2'),
#              ('770585517859700736',
#               ', including activating taste receptors to make salt taste saltier and sugar taste sweeter, activating a special receptor in your brain that'),
#              ('595980153529999360',
#               '," as in "bend over boyfriend"). It’s a lot easier to talk about when you have a cute verb to'),
#              ('4vff7n', ', a danger to the Republic.’ Special:'),
#              ('806153730206892032',
#               ', has failed to unite the country as President George W. Bush did after 9/11. Instead, he has ranted and attacked the'),
#              ('388308677494444032', ', Finn Wittro')])

# %%
metric = load_metric("squad_v2")
formatted_predictions = [{"id": k, "prediction_text": v, "no_answer_probability": 0.0} for k, v in final_predictions.items()]
references = [{"id": ex["id"], "answers": ex["answers"]} for ex in valid_dict['valid']]
metric.compute(predictions=formatted_predictions, references=references)
# Out:
# <ipython-input-31-3bdf1938f8b2>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("squad_v2")
# Downloading builder script:   0%|          | 0.00/2.25k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.19k [00:00<?, ?B/s]
# {'exact': 0.0,
#  'f1': 3.1715596833699937,
#  'total': 335,
#  'HasAns_exact': 0.0,
#  'HasAns_f1': 3.1715596833699937,
#  'HasAns_total': 335,
#  'best_exact': 0.0,
#  'best_exact_thresh': 0.0,
#  'best_f1': 3.1715596833699937,
#  'best_f1_thresh': 0.0}

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (0.8.10)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (4.9.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (2022.10.31)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (1.22.4)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.7.0 sacrebleu-2.3.1

# %%
metric = load_metric("sacrebleu")
formatted_predictions = [{"id": k, "prediction_text": v, "no_answer_probability": 0.0} for k, v in final_predictions.items()]
references = [{"id": ex["id"], "answers": ex["answers"]} for ex in valid_dict['valid']]
# metric.compute(predictions=formatted_predictions, references=references)
metric.compute(predictions=formatted_predictions, references=references, smooth_method='floor', smooth_value=0.2)
# Out:
# {'score': 0.0,
#  'counts': [0, 0, 0, 0],
#  'totals': [11007, 10672, 10337, 10002],
#  'precisions': [0.0, 0.0, 0.0, 0.0],
#  'bp': 1.0,
#  'sys_len': 11007,
#  'ref_len': 335}
